# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariaranbo16/Pandas/blob/main/Taller_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

encuesta = pd.DataFrame (
    {
        "Julia": ["Me gustó", "Fue horrible"],
        "Pedro": ["Fue delicioso", "No estuvo mal"],
    },
    index = ["Restaurante_1","Restaurante_2"]
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante_1      Me gustó  Fue delicioso
# Restaurante_2  Fue horrible  No estuvo mal

# %% [markdown]
# Estudiante_1, Estudiante_2, Estudiante_3
# 34, 23, 45
# 45, 10, 46
# 25, 30, 46
#
# Guardas como datos.csv

# %% [markdown]
# ## Cargar archivos CSV en un dataframe

# %%
# Leer archivo CSV

miCSV = pd.read_csv ("Datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1   Estudiante_2   Estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %%
miTitanic = pd.read_csv ("titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miTitanic.describe ()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.366029
# std     120.810458    0.482295
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
# Forma de cambiar las columnas
miTitanic.rename (columns= {"Survived": "Sobreviviente"}, inplace = True)
miTitanic.head()
# Out:
#    PassengerId  Sobreviviente
# 0          892              0
# 1          893              0
# 2          894              0
# 3          895              0
# 4          896              1

# %%
# Sumar los sobrevivientes del titanic
import numpy as np

miSobrevivienteFiltrado = miTitanic ['Sobreviviente']
miSobrevivienteFiltrado.sum()
# Out:
# 153

# %%
miEdad = pd.read_csv ("edad.csv")
miEdad.shape
miEdad.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
miEdad.describe ()
# Out:
#          age   ethnicity      gender
# count  944.0  944.000000  944.000000
# mean     1.0    2.092161    0.319915
# std      0.0    1.302979    0.466691
# min      1.0    0.000000    0.000000
# 25%      1.0    2.000000    0.000000
# 50%      1.0    2.000000    0.000000
# 75%      1.0    3.000000    1.000000
# max      1.0    4.000000    1.000000

# %%
# Forma de cambiar las columnas
miEdad.rename (columns= {"age": "Edad"}, inplace = True)
miEdad.rename (columns= {"ethnicity": "Etnia"}, inplace = True)
miEdad.rename (columns= {"gender": "Género"}, inplace = True)
miEdad.rename (columns= {"img_name": "Nombre de la imágen"}, inplace = True)
miEdad.rename (columns= {"pixels": "Pixeles"}, inplace = True)
miEdad.head ()
# Out:
#    Edad  Etnia  Género             Nombre de la imágen  \
# 0     1      2       0  20161219203650636.jpg.chip.jpg
# 1     1      2       0  20161219222752047.jpg.chip.jpg
# 2     1      2       0  20161219222832191.jpg.chip.jpg
# 3     1      2       0  20161220144911423.jpg.chip.jpg
# 4     1      2       0  20161220144914327.jpg.chip.jpg
#
#                                              Pixeles
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
misEdad = miEdad ["Edad"]
misEdad.count ()
# Out:
# 944

# %%
misEdad.product()
# Out:
# 1

# %% [markdown]
# # Seleccionar filas específicas (Flitrar filas)

# %%
miEdadFiltrado = miEdad [misEdad>0]
miEdadFiltrado.count ()
# Out:
# Edad                   944
# Etnia                  944
# Género                 944
# Nombre de la imágen    944
# Pixeles                944
# dtype: int64

# %%
# Sumar los pixeles
